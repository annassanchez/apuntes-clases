# %%
# !pip install fuzzywuzzy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from collections import Counter
from fuzzywuzzy import process, fuzz
import pickle
# Out:
# /usr/local/lib/python3.10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # Cargamos los datos

# %%
# cargamos el csv donde tenemos todos los títulos que tenemos en Netflix
df_titulos = pd.read_csv("data/netflix_titles.csv", index_col = 0 )
df_titulos.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
# cargamos el csv donde tenemos todas las producciones de Netflix
df_original = pd.read_csv("data/netflix_originals.csv", index_col = 0)
df_original.head(2)
# Out:
#              Title        Genre         Premiere  Runtime  IMDB Score  \
# 0  Enter the Anime  Documentary   August 5, 2019       58         2.5
# 1      Dark Forces     Thriller  August 21, 2020       81         2.6
#
#            Language
# 0  English/Japanese
# 1           Spanish

# %%
df_titulos.shape
# Out:
# (8807, 12)

# %%
df_original.shape
# Out:
# (513, 6)

# %% [markdown]
# ## Juntamos los dos dataframes

# %%
df = df_titulos.merge(df_original, left_on = "title", right_on = "Title",how = "inner")
df.head(2)
# Out:
#   show_id   type                 title          director  \
# 0      s1  Movie  Dick Johnson Is Dead   Kirsten Johnson
# 1    s142  Movie            Extraction  Steven C. Miller
#
#                                                 cast  \
# 0                                                NaN
# 1  Bruce Willis, Kellan Lutz, Gina Carano, D.B. S...
#
#                                  country          date_added  release_year  \
# 0                          United States  September 25, 2021          2020
# 1  United States, United Kingdom, Canada   September 1, 2021          2015
#
#   rating duration           listed_in  \
# 0  PG-13   90 min       Documentaries
# 1      R   82 min  Action & Adventure
#
#                                          description                 Title  \
# 0  As her father nears the end of his life, filmm...  Dick Johnson Is Dead
# 1  When a retired CIA agent is kidnapped, his son...            Extraction
#
#          Genre         Premiere  Runtime  IMDB Score Language
# 0  Documentary  October 2, 2020       90         7.5  English
# 1       Action   April 24, 2020      117         6.7  English

# %%
df.shape
# Out:
# (513, 18)

# %%
df.drop(["release_year", "Title", "Runtime", "show_id", "description" ], axis = 1, inplace = True)
df.head(1)
# Out:
#     type                 title         director cast        country  \
# 0  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added rating duration      listed_in        Genre  \
# 0  September 25, 2021  PG-13   90 min  Documentaries  Documentary
#
#           Premiere  IMDB Score Language
# 0  October 2, 2020         7.5  English

# %% [markdown]
# Tenemos columnas en mayúsculas y otras en minúsculas, y con espacios. Vamos a intentar homogeneizarlo:

# %%
nuevas_columnas = {col: col.strip().replace(" ", "_").lower() for col in df.columns}
nuevas_columnas
# Out:
# {'type': 'type',
#  'title': 'title',
#  'director': 'director',
#  'cast': 'cast',
#  'country': 'country',
#  'date_added': 'date_added',
#  'rating': 'rating',
#  'duration': 'duration',
#  'listed_in': 'listed_in',
#  'Genre': 'genre',
#  'Premiere': 'premiere',
#  'IMDB Score': 'imdb_score',
#  'Language': 'language'}

# %%
df.rename(columns = nuevas_columnas, inplace = True)
df.head(1)
# Out:
#     type                 title         director cast        country  \
# 0  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added rating duration      listed_in        genre  \
# 0  September 25, 2021  PG-13   90 min  Documentaries  Documentary
#
#           premiere  imdb_score language
# 0  October 2, 2020         7.5  English

# %% [markdown]
# # Análisis exploratorio

# %%
df.shape
# Out:
# (513, 13)

# %%
df.dtypes
# Out:
# type           object
# title          object
# director       object
# cast           object
# country        object
# date_added     object
# rating         object
# duration       object
# listed_in      object
# genre          object
# premiere       object
# imdb_score    float64
# language       object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 513 entries, 0 to 512
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   type        513 non-null    object
#  1   title       513 non-null    object
#  2   director    491 non-null    object
#  3   cast        422 non-null    object
#  4   country     499 non-null    object
#  5   date_added  513 non-null    object
#  6   rating      513 non-null    object
#  7   duration    276 non-null    object
#  8   listed_in   513 non-null    object
#  9   genre       513 non-null    object
#  10  premiere    513 non-null    object
#  11  imdb_score  513 non-null    float64
#  12  language    513 non-null    object
# dtypes: float64(1), object(12)
# memory usage: 56.1+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# type            0
# title           0
# director       22
# cast           91
# country        14
# date_added      0
# rating          0
# duration      237
# listed_in       0
# genre           0
# premiere        0
# imdb_score      0
# language        0
# dtype: int64

# %%
df.describe().T
# Out:
#             count      mean      std  min  25%  50%  75%  max
# imdb_score  513.0  6.210916  0.96885  2.5  5.6  6.3  6.9  9.0

# %%
df.describe(include = "object").T
# Out:
#            count unique                   top freq
# type         513      1                 Movie  513
# title        513    513  Dick Johnson Is Dead    1
# director     491    462                   McG    3
# cast         422    421          Shawn Mendes    2
# country      499     81         United States  274
# date_added   513    354      October 18, 2019    5
# rating       513     10                 TV-MA  254
# duration     276     86                98 min   20
# listed_in    513    103         Documentaries   69
# genre        513    106           Documentary  132
# premiere     513    350       October 2, 2020    5
# language     513     37               English  352

# %%
#df.describe(include = "all").T

# %%
df.drop(["type"], axis = 1, inplace = True)
df.head(1)
# Out:
#                   title         director cast        country  \
# 0  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added rating duration      listed_in        genre  \
# 0  September 25, 2021  PG-13   90 min  Documentaries  Documentary
#
#           premiere  imdb_score language
# 0  October 2, 2020         7.5  English

# %%
df_cat = df.select_dtypes(include = "object")
df_cat.head(1)
# Out:
#                   title         director cast        country  \
# 0  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added rating duration      listed_in        genre  \
# 0  September 25, 2021  PG-13   90 min  Documentaries  Documentary
#
#           premiere language
# 0  October 2, 2020  English

# %%
df_num = df.select_dtypes(include = np.number)
df_num.head(2)
# Out:
#    imdb_score
# 0         7.5
# 1         6.7

# %%
for col in df_cat.columns[1:]:
    print(f"La cantidad de valores unicos para la columa {col.upper()} es {len(df[col].unique())}")
    display(pd.DataFrame(df_cat[col].value_counts()))
    print("------")
# Out:
# La cantidad de valores unicos para la columa DIRECTOR es 463
#                        director
# McG                           3
# Amy Poehler                   2
# Christopher Guest             2
# Noah Baumbach                 2
# Michael Tiddes                2
# ...                         ...
# Gina Prince-Bythewood         1
# Sue Ding                      1
# Stéphane de Freitas           1
# Stefano Mordini               1
# David Sampliner               1
#
# [462 rows x 1 columns]
# ------
# La cantidad de valores unicos para la columa CAST es 422
#                                                     cast
# Shawn Mendes                                           2
# Bruce Willis, Kellan Lutz, Gina Carano, D.B. Sw...     1
# Loudon Wainwright III                                  1
# Liam Neeson, James Franco, Tim Blake Nelson, To...     1
# Madeline Brewer, Patch Darragh, Melora Walters,...     1
# ...                                                  ...
# Marta Etura, Leonardo Sbaraglia, Carlos Librado...     1
# Fulu Mugovhani, Tumi Morake, Bohang Moeko, Yond...     1
# Nawazuddin Siddiqui, Radhika Apte, Khalid Tyabj...     1
# Nicolas Anelka                                         1
# David Sampliner                                        1
#
# [421 rows x 1 columns]
# ------
# La cantidad de valores unicos para la columa COUNTRY es 82
#                                         country
# United States                               274
# India                                        35
# Italy                                        13
# United Kingdom                               13
# Spain                                        12
# ...                                         ...
# Philippines, United States                    1
# United Kingdom, Japan, United States          1
# Spain, United Kingdom                         1
# United Kingdom, Hungary, Australia            1
# United Kingdom, Ukraine, United States        1
#
# [81 rows x 1 columns]
# ------
# La cantidad de valores unicos para la columa DATE_ADDED es 354
#                    date_added
# October 18, 2019            5
# November 1, 2019            5
# October 30, 2020            4
# April 10, 2020              4
# February 5, 2021            4
# ...                       ...
# February 12, 2020           1
# February 14, 2020           1
# March 8, 2020               1
# March 13, 2020              1
# March 6, 2015               1
#
# [354 rows x 1 columns]
# ------
# La cantidad de valores unicos para la columa RATING es 10
#        rating
# TV-MA     254
# TV-14      94
# TV-PG      57
# R          47
# PG-13      23
# TV-G       16
# PG         11
# TV-Y7       5
# TV-Y        5
# G           1
# ------
# La cantidad de valores unicos para la columa DURATION es 87
#          duration
# 98 min         20
# 90 min         13
# 107 min        12
# 113 min        12
# 104 min        11
# ...           ...
# 111 min         1
# 148 min         1
# 145 min         1
# 129 min         1
# 131 min         1
#
# [86 rows x 1 columns]
# ------
# La cantidad de valores unicos para la columa LISTED_IN es 103
#                                                     listed_in
# Documentaries                                              69
# Dramas                                                     22
# Dramas, International Movies                               21
# Documentaries, Music & Musicals                            20
# Comedies                                                   19
# ...                                                       ...
# Independent Movies, International Movies, Thril...          1
# Comedies, Dramas, LGBTQ Movies                              1
# Horror Movies                                               1
# Children & Family Movies, Comedies, Sci-Fi & Fa...          1
# Documentaries, Stand-Up Comedy                              1
#
# [103 rows x 1 columns]
# ------
# La cantidad de valores unicos para la columa GENRE es 106
#                      genre
# Documentary            132
# Drama                   73
# Comedy                  42
# Romantic comedy         35
# Thriller                33
# ...                    ...
# Superhero/Action         1
# Dance comedy             1
# Animation/Superhero      1
# Drama/Horror             1
# Mockumentary             1
#
# [106 rows x 1 columns]
# ------
# La cantidad de valores unicos para la columa PREMIERE es 350
#                    premiere
# October 2, 2020           5
# November 1, 2019          5
# October 18, 2019          5
# April 10, 2020            4
# December 7, 2018          4
# ...                     ...
# January 17, 2020          1
# January 1, 2020           1
# December 26, 2019         1
# December 20, 2019         1
# December 13, 2014         1
#
# [350 rows x 1 columns]
# ------
# La cantidad de valores unicos para la columa LANGUAGE es 37
#                             language
# English                          352
# Hindi                             28
# Spanish                           26
# French                            18
# Italian                           14
# Indonesian                         9
# Portuguese                         9
# English/Spanish                    5
# Japanese                           5
# Korean                             5
# Turkish                            4
# German                             4
# Marathi                            3
# Polish                             3
# English/Hindi                      2
# Thai                               2
# Filipino                           2
# Dutch                              2
# English/Japanese                   2
# English/Akan                       1
# English/Russian                    1
# English/Mandarin                   1
# English/Korean                     1
# Khmer/English/French               1
# Spanish/Basque                     1
# Tamil                              1
# Spanish/Catalan                    1
# Norwegian                          1
# English/Swedish                    1
# English/Taiwanese/Mandarin         1
# Spanish/English                    1
# Thia/English                       1
# Malay                              1
# Bengali                            1
# English/Arabic                     1
# Swedish                            1
# English/Ukranian/Russian           1
# ------

# %%
df.drop(["listed_in"], axis = 1, inplace = True)
df.head(1)
# Out:
#                   title         director cast        country  \
# 0  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#            date_added rating duration        genre         premiere  \
# 0  September 25, 2021  PG-13   90 min  Documentary  October 2, 2020
#
#    imdb_score language
# 0         7.5  English

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# director     22
# cast         91
# country      14
# duration    237
# dtype: int64

# %%
df[["country", "cast", "director"]] = df[["country", "cast", "director"]].fillna("Desconocido")

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# duration    237
# dtype: int64

# %%
df.head()
# Out:
#                   title             director  \
# 0  Dick Johnson Is Dead      Kirsten Johnson
# 1            Extraction     Steven C. Miller
# 2            Prime Time         Jakub Piątek
# 3          Blue Miracle       Julio Quintana
# 4             Ghost Lab  Paween Purijitpanya
#
#                                                 cast  \
# 0                                        Desconocido
# 1  Bruce Willis, Kellan Lutz, Gina Carano, D.B. S...
# 2  Bartosz Bielenia, Magdalena Popławska, Andrzej...
# 3  Jimmy Gonzales, Dennis Quaid, Anthony Gonzalez...
# 4  Thanapob Leeratanakachorn, Paris Intarakomalya...
#
#                                  country          date_added rating duration  \
# 0                          United States  September 25, 2021  PG-13   90 min
# 1  United States, United Kingdom, Canada   September 1, 2021      R   82 min
# 2                            Desconocido       June 30, 2021  TV-MA      NaN
# 3                          United States        May 27, 2021  TV-PG      NaN
# 4                               Thailand        May 27, 2021  TV-MA  118 min
#
#          genre         premiere  imdb_score language
# 0  Documentary  October 2, 2020         7.5  English
# 1       Action   April 24, 2020         6.7  English
# 2     Thriller   April 14, 2021         5.7   Polish
# 3        Drama     May 27, 2021         6.7  English
# 4       Horror     May 26, 2021         5.2     Thai

# %%
df["duration"] = df["duration"].str.split(" ", expand = True).get(0)

# %%
df.head()
# Out:
#                   title             director  \
# 0  Dick Johnson Is Dead      Kirsten Johnson
# 1            Extraction     Steven C. Miller
# 2            Prime Time         Jakub Piątek
# 3          Blue Miracle       Julio Quintana
# 4             Ghost Lab  Paween Purijitpanya
#
#                                                 cast  \
# 0                                        Desconocido
# 1  Bruce Willis, Kellan Lutz, Gina Carano, D.B. S...
# 2  Bartosz Bielenia, Magdalena Popławska, Andrzej...
# 3  Jimmy Gonzales, Dennis Quaid, Anthony Gonzalez...
# 4  Thanapob Leeratanakachorn, Paris Intarakomalya...
#
#                                  country          date_added rating duration  \
# 0                          United States  September 25, 2021  PG-13       90
# 1  United States, United Kingdom, Canada   September 1, 2021      R       82
# 2                            Desconocido       June 30, 2021  TV-MA      NaN
# 3                          United States        May 27, 2021  TV-PG      NaN
# 4                               Thailand        May 27, 2021  TV-MA      118
#
#          genre         premiere  imdb_score language
# 0  Documentary  October 2, 2020         7.5  English
# 1       Action   April 24, 2020         6.7  English
# 2     Thriller   April 14, 2021         5.7   Polish
# 3        Drama     May 27, 2021         6.7  English
# 4       Horror     May 26, 2021         5.2     Thai

# %%
df.dtypes
# Out:
# title          object
# director       object
# cast           object
# country        object
# date_added     object
# rating         object
# duration       object
# genre          object
# premiere       object
# imdb_score    float64
# language       object
# dtype: object

# %%
df["duration2"] = pd.to_numeric(df["duration"])

# %%
df.dtypes
# Out:
# title          object
# director       object
# cast           object
# country        object
# date_added     object
# rating         object
# duration       object
# genre          object
# premiere       object
# imdb_score    float64
# language       object
# duration2     float64
# dtype: object

# %%
df["duration3"] = df["duration"].astype(float)

# %%
df.dtypes
# Out:
# title          object
# director       object
# cast           object
# country        object
# date_added     object
# rating         object
# duration       object
# genre          object
# premiere       object
# imdb_score    float64
# language       object
# duration2     float64
# duration3     float64
# dtype: object

# %%
df.drop(["duration","duration2" ], axis = 1, inplace = True)
df.head()
# Out:
#                   title             director  \
# 0  Dick Johnson Is Dead      Kirsten Johnson
# 1            Extraction     Steven C. Miller
# 2            Prime Time         Jakub Piątek
# 3          Blue Miracle       Julio Quintana
# 4             Ghost Lab  Paween Purijitpanya
#
#                                                 cast  \
# 0                                        Desconocido
# 1  Bruce Willis, Kellan Lutz, Gina Carano, D.B. S...
# 2  Bartosz Bielenia, Magdalena Popławska, Andrzej...
# 3  Jimmy Gonzales, Dennis Quaid, Anthony Gonzalez...
# 4  Thanapob Leeratanakachorn, Paris Intarakomalya...
#
#                                  country          date_added rating  \
# 0                          United States  September 25, 2021  PG-13
# 1  United States, United Kingdom, Canada   September 1, 2021      R
# 2                            Desconocido       June 30, 2021  TV-MA
# 3                          United States        May 27, 2021  TV-PG
# 4                               Thailand        May 27, 2021  TV-MA
#
#          genre         premiere  imdb_score language  duration3
# 0  Documentary  October 2, 2020         7.5  English       90.0
# 1       Action   April 24, 2020         6.7  English       82.0
# 2     Thriller   April 14, 2021         5.7   Polish        NaN
# 3        Drama     May 27, 2021         6.7  English        NaN
# 4       Horror     May 26, 2021         5.2     Thai      118.0

# %%
df.describe().T
# Out:
#             count       mean        std  min    25%    50%    75%    max
# imdb_score  513.0   6.210916   0.968850  2.5   5.60    6.3    6.9    9.0
# duration3   276.0  93.807971  34.883954  5.0  79.75  101.0  119.0  209.0

# %%
df["duration3"] = df["duration3"].fillna(df["duration3"].median())

# %%
df.head(10)
# Out:
#                          title             director  \
# 0         Dick Johnson Is Dead      Kirsten Johnson
# 1                   Extraction     Steven C. Miller
# 2                   Prime Time         Jakub Piątek
# 3                 Blue Miracle       Julio Quintana
# 4                    Ghost Lab  Paween Purijitpanya
# 5  Baggio: The Divine Ponytail    Letizia Lamartire
# 6         Nail Bomber: Manhunt        Daniel Vernon
# 7             Army of the Dead          Zack Snyder
# 8           Sardar Ka Grandson        Kaashvie Nair
# 9                        Ferry    Cecilia Verheyden
#
#                                                 cast  \
# 0                                        Desconocido
# 1  Bruce Willis, Kellan Lutz, Gina Carano, D.B. S...
# 2  Bartosz Bielenia, Magdalena Popławska, Andrzej...
# 3  Jimmy Gonzales, Dennis Quaid, Anthony Gonzalez...
# 4  Thanapob Leeratanakachorn, Paris Intarakomalya...
# 5  Andrea Arcangeli, Valentina Bellè, Andrea Penn...
# 6                                        Desconocido
# 7  Dave Bautista, Ella Purnell, Omari Hardwick, G...
# 8  Arjun Kapoor, Neena Gupta, Rakul Preet Singh, ...
# 9  Frank Lammers, Elise Schaap, Huub Stapel, Moni...
#
#                                  country          date_added rating  \
# 0                          United States  September 25, 2021  PG-13
# 1  United States, United Kingdom, Canada   September 1, 2021      R
# 2                            Desconocido       June 30, 2021  TV-MA
# 3                          United States        May 27, 2021  TV-PG
# 4                               Thailand        May 27, 2021  TV-MA
# 5                                  Italy        May 26, 2021  TV-MA
# 6                            Desconocido        May 26, 2021  TV-MA
# 7                          United States        May 21, 2021      R
# 8                                  India        May 18, 2021  TV-14
# 9                   Belgium, Netherlands        May 14, 2021  TV-MA
#
#           genre         premiere  imdb_score language  duration3
# 0   Documentary  October 2, 2020         7.5  English       90.0
# 1        Action   April 24, 2020         6.7  English       82.0
# 2      Thriller   April 14, 2021         5.7   Polish      101.0
# 3         Drama     May 27, 2021         6.7  English      101.0
# 4        Horror     May 26, 2021         5.2     Thai      118.0
# 5        Biopic     May 26, 2021         6.2  Italian      101.0
# 6   Documentary     May 26, 2021         6.3  English       73.0
# 7  Zombie/Heist     May 21, 2021         5.9  English      148.0
# 8        Comedy     May 18, 2021         4.1    Hindi      140.0
# 9   Crime drama     May 14, 2021         7.1    Dutch      107.0

# %%
df["premiere"] = pd.to_datetime(df["premiere"])
df["date_added"] = pd.to_datetime(df["date_added"])

# %%
df.dtypes
# Out:
# title                 object
# director              object
# cast                  object
# country               object
# date_added    datetime64[ns]
# rating                object
# genre                 object
# premiere      datetime64[ns]
# imdb_score           float64
# language              object
# duration3            float64
# dtype: object

# %%
df.head()
# Out:
#                   title             director  \
# 0  Dick Johnson Is Dead      Kirsten Johnson
# 1            Extraction     Steven C. Miller
# 2            Prime Time         Jakub Piątek
# 3          Blue Miracle       Julio Quintana
# 4             Ghost Lab  Paween Purijitpanya
#
#                                                 cast  \
# 0                                        Desconocido
# 1  Bruce Willis, Kellan Lutz, Gina Carano, D.B. S...
# 2  Bartosz Bielenia, Magdalena Popławska, Andrzej...
# 3  Jimmy Gonzales, Dennis Quaid, Anthony Gonzalez...
# 4  Thanapob Leeratanakachorn, Paris Intarakomalya...
#
#                                  country date_added rating        genre  \
# 0                          United States 2021-09-25  PG-13  Documentary
# 1  United States, United Kingdom, Canada 2021-09-01      R       Action
# 2                            Desconocido 2021-06-30  TV-MA     Thriller
# 3                          United States 2021-05-27  TV-PG        Drama
# 4                               Thailand 2021-05-27  TV-MA       Horror
#
#     premiere  imdb_score language  duration3
# 0 2020-10-02         7.5  English       90.0
# 1 2020-04-24         6.7  English       82.0
# 2 2021-04-14         5.7   Polish      101.0
# 3 2021-05-27         6.7  English      101.0
# 4 2021-05-26         5.2     Thai      118.0

# %%
df["cast"] = df["cast"].str.split(",")

# %%
df.head()
# Out:
#                   title             director  \
# 0  Dick Johnson Is Dead      Kirsten Johnson
# 1            Extraction     Steven C. Miller
# 2            Prime Time         Jakub Piątek
# 3          Blue Miracle       Julio Quintana
# 4             Ghost Lab  Paween Purijitpanya
#
#                                                 cast  \
# 0                                      [Desconocido]
# 1  [Bruce Willis,  Kellan Lutz,  Gina Carano,  D....
# 2  [Bartosz Bielenia,  Magdalena Popławska,  Andr...
# 3  [Jimmy Gonzales,  Dennis Quaid,  Anthony Gonza...
# 4  [Thanapob Leeratanakachorn,  Paris Intarakomal...
#
#                                  country date_added rating        genre  \
# 0                          United States 2021-09-25  PG-13  Documentary
# 1  United States, United Kingdom, Canada 2021-09-01      R       Action
# 2                            Desconocido 2021-06-30  TV-MA     Thriller
# 3                          United States 2021-05-27  TV-PG        Drama
# 4                               Thailand 2021-05-27  TV-MA       Horror
#
#     premiere  imdb_score language  duration3
# 0 2020-10-02         7.5  English       90.0
# 1 2020-04-24         6.7  English       82.0
# 2 2021-04-14         5.7   Polish      101.0
# 3 2021-05-27         6.7  English      101.0
# 4 2021-05-26         5.2     Thai      118.0

# %%
df["cast"][1]
# Out:
# ['Bruce Willis',
#  ' Kellan Lutz',
#  ' Gina Carano',
#  ' D.B. Sweeney',
#  ' Joshua Mikel',
#  ' Steve Coulter',
#  ' Dan Bilzerian',
#  ' Heather Johansen']

# %%
df.shape
# Out:
# (513, 11)

# %%
df_actor = df.explode("cast")
df_actor.head(1)
# Out:
#                   title         director         cast        country  \
# 0  Dick Johnson Is Dead  Kirsten Johnson  Desconocido  United States
#
#   date_added rating        genre   premiere  imdb_score language  duration3
# 0 2021-09-25  PG-13  Documentary 2020-10-02         7.5  English       90.0

# %%
df_actor = df_actor[["title", "cast"]]
df_actor.head()
# Out:
#                   title           cast
# 0  Dick Johnson Is Dead    Desconocido
# 1            Extraction   Bruce Willis
# 1            Extraction    Kellan Lutz
# 1            Extraction    Gina Carano
# 1            Extraction   D.B. Sweeney

# %%
df["director"][16]
# Out:
# 'Robert Pulcini, Shari Springer Berman'

# %%
df["director"].unique().tolist()[:10]
# Out:
# ['Kirsten Johnson',
#  'Steven C. Miller',
#  'Jakub Piątek',
#  'Julio Quintana',
#  'Paween Purijitpanya',
#  'Letizia Lamartire',
#  'Daniel Vernon',
#  'Zack Snyder',
#  'Kaashvie Nair',
#  'Cecilia Verheyden']

# %%
df["director"] = df["director"].str.split(",")
df_director = df.explode("director")
#df_director.head(20)

# %%
df.head(1)
# Out:
#                   title           director           cast        country  \
# 0  Dick Johnson Is Dead  [Kirsten Johnson]  [Desconocido]  United States
#
#   date_added rating        genre   premiere  imdb_score language  duration3
# 0 2021-09-25  PG-13  Documentary 2020-10-02         7.5  English       90.0

# %%
df_actor.head(1)
# Out:
#                   title         cast
# 0  Dick Johnson Is Dead  Desconocido

# %%
df_director.head(1)
# Out:
#                   title         director           cast        country  \
# 0  Dick Johnson Is Dead  Kirsten Johnson  [Desconocido]  United States
#
#   date_added rating        genre   premiere  imdb_score language  duration3
# 0 2021-09-25  PG-13  Documentary 2020-10-02         7.5  English       90.0

# %%
df_actor["cast"].value_counts()
# Out:
# Desconocido           91
# Adam Sandler           7
#  Maya Rudolph          6
#  Andrew Bachelor       5
#  Lakeith Stanfield     4
#                       ..
#  Cree Cicchino         1
#  Lucas Jaye            1
#  Karla Souza           1
#  Enuka Okuma           1
# David Sampliner        1
# Name: cast, Length: 3005, dtype: int64

# %%
df_groupby_actor = df_actor.groupby("cast").count()
df_groupby_actor
# Out:
#                   title
# cast
#  Aakshath Das         1
#  Aaron Abrams         1
#  Aaron Douglas        1
#  Aaron Guy            1
#  Aaron Stanford       1
# ...                 ...
# Zion Clark            1
# Zoey Deutch           1
# Álvaro Cervantes      1
# Çağatay Ulusoy        1
# Ṣọpẹ́ Dìrísù          1
#
# [3005 rows x 1 columns]

# %%
df_groupby_actor = df_groupby_actor.sort_values(by = "title", ascending = False)

# %%
df_groupby_actor.head(15)
# Out:
#                      title
# cast
# Desconocido             91
# Adam Sandler             7
#  Maya Rudolph            6
#  Andrew Bachelor         5
#  Keegan-Michael Key      4
#  Robbie Amell            4
#  Jacki Weaver            4
#  Rob Schneider           4
#  Nick Swardson           4
#  Lakeith Stanfield       4
#  Zachary Quinto          4
#  Ken Marino              4
#  Shea Whigham            3
#  Jharrel Jerome          3
#  Jesse Plemons           3

# %%
top_10_actor = df_groupby_actor.iloc[1:11, :]
top_10_actor
# Out:
#                      title
# cast
# Adam Sandler             7
#  Maya Rudolph            6
#  Andrew Bachelor         5
#  Keegan-Michael Key      4
#  Robbie Amell            4
#  Jacki Weaver            4
#  Rob Schneider           4
#  Nick Swardson           4
#  Lakeith Stanfield       4
#  Zachary Quinto          4

# %%
top_10_actor = top_10_actor.index.tolist()
top_10_actor
# Out:
# ['Adam Sandler',
#  ' Maya Rudolph',
#  ' Andrew Bachelor',
#  ' Keegan-Michael Key',
#  ' Robbie Amell',
#  ' Jacki Weaver',
#  ' Rob Schneider',
#  ' Nick Swardson',
#  ' Lakeith Stanfield',
#  ' Zachary Quinto']

# %%
top_10_actor = [actor.strip() for actor in top_10_actor]
top_10_actor
# Out:
# ['Adam Sandler',
#  'Maya Rudolph',
#  'Andrew Bachelor',
#  'Keegan-Michael Key',
#  'Robbie Amell',
#  'Jacki Weaver',
#  'Rob Schneider',
#  'Nick Swardson',
#  'Lakeith Stanfield',
#  'Zachary Quinto']

# %%
with open("data/top_ten_actor.pkl", "wb") as actor: 
    pickle.dump(top_10_actor, actor)

# %%
df_director.head()
# Out:
#                   title             director  \
# 0  Dick Johnson Is Dead      Kirsten Johnson
# 1            Extraction     Steven C. Miller
# 2            Prime Time         Jakub Piątek
# 3          Blue Miracle       Julio Quintana
# 4             Ghost Lab  Paween Purijitpanya
#
#                                                 cast  \
# 0                                      [Desconocido]
# 1  [Bruce Willis,  Kellan Lutz,  Gina Carano,  D....
# 2  [Bartosz Bielenia,  Magdalena Popławska,  Andr...
# 3  [Jimmy Gonzales,  Dennis Quaid,  Anthony Gonza...
# 4  [Thanapob Leeratanakachorn,  Paris Intarakomal...
#
#                                  country date_added rating        genre  \
# 0                          United States 2021-09-25  PG-13  Documentary
# 1  United States, United Kingdom, Canada 2021-09-01      R       Action
# 2                            Desconocido 2021-06-30  TV-MA     Thriller
# 3                          United States 2021-05-27  TV-PG        Drama
# 4                               Thailand 2021-05-27  TV-MA       Horror
#
#     premiere  imdb_score language  duration3
# 0 2020-10-02         7.5  English       90.0
# 1 2020-04-24         6.7  English       82.0
# 2 2021-04-14         5.7   Polish      101.0
# 3 2021-05-27         6.7  English      101.0
# 4 2021-05-26         5.2     Thai      118.0

# %%
df["genre"].unique()
# Out:
# array(['Documentary', 'Action', 'Thriller', 'Drama', 'Horror', 'Biopic',
#        'Zombie/Heist', 'Comedy', 'Crime drama', 'Psychological thriller',
#        'Science fiction thriller', 'Animated musical comedy',
#        'Psychological thriller drama', 'Superhero-Comedy',
#        'Romantic comedy', 'Christian musical',
#        'Hidden-camera prank comedy', 'Comedy-drama',
#        'Romantic teen drama', 'Romantic drama', 'Science fiction',
#        'Action/Science fiction', 'Animation / Short', 'Superhero',
#        'Aftershow / Interview', 'Musical', 'Animation', 'Concert Film',
#        'Christmas comedy', 'Stop Motion', 'Family/Christmas musical',
#        'Anthology/Dark comedy', 'Mystery', 'Romantic comedy/Holiday',
#        'Variety show', 'Animation/Musical/Adventure', 'Romantic thriller',
#        'Comedy/Fantasy/Family', 'Horror comedy', 'Action comedy',
#        'Family', 'Comedy/Horror', 'Drama/Horror', 'Animation/Superhero',
#        'Dance comedy', 'Superhero/Action', 'Romantic teenage drama',
#        'Musical comedy', 'Family/Comedy-drama', 'Romance',
#        'Anime/Fantasy', 'War drama', 'Heist film/Thriller',
#        'Animation/Comedy/Adventure', 'Satire', 'Anime / Short',
#        'Sports film', 'Anime/Science fiction', 'Political thriller',
#        'Horror anthology', 'Science fiction/Drama', 'Family film',
#        'Animation/Christmas/Comedy/Adventure', 'Adventure-romance',
#        'Historical drama', 'Coming-of-age comedy-drama',
#        'Animation / Science Fiction', 'Animation / Comedy',
#        'Spy thriller', 'Comedy mystery', 'Science fiction adventure',
#        'Horror-thriller', 'Comedy / Musical', 'Action-thriller',
#        'Drama-Comedy', 'Romance drama', 'Sports-drama', 'One-man show',
#        'Adventure', 'Christmas/Fantasy/Adventure/Comedy',
#        'Psychological horror', 'Western', 'Historical-epic',
#        'Mentalism special', 'Black comedy', 'Science fiction/Thriller',
#        'Adventure/Comedy', 'Teen comedy-drama', 'Action/Comedy',
#        'Musical/Western/Fantasy', 'Science fiction/Mystery',
#        'Biographical/Comedy', 'Horror thriller', 'Urban fantasy',
#        'Dark comedy', 'Horror/Crime drama', 'Action thriller',
#        'Teen comedy horror', 'Comedy horror', 'Action-adventure',
#        'Crime thriller', 'War-Comedy', 'War', 'Heist',
#        'Science fiction/Action', 'Mockumentary'], dtype=object)

# %%
df["genre"] = df["genre"].str.lower()

# %%
df["genre"].unique()[:10]
# Out:
# array(['documentary', 'action', 'thriller', 'drama', 'horror', 'biopic',
#        'zombie/heist', 'comedy', 'crime drama', 'psychological thriller'],
#       dtype=object)

# %%
df["genre2"] = df["genre"].str.split("/")

# %%
df.head()
# Out:
#                   title               director  \
# 0  Dick Johnson Is Dead      [Kirsten Johnson]
# 1            Extraction     [Steven C. Miller]
# 2            Prime Time         [Jakub Piątek]
# 3          Blue Miracle       [Julio Quintana]
# 4             Ghost Lab  [Paween Purijitpanya]
#
#                                                 cast  \
# 0                                      [Desconocido]
# 1  [Bruce Willis,  Kellan Lutz,  Gina Carano,  D....
# 2  [Bartosz Bielenia,  Magdalena Popławska,  Andr...
# 3  [Jimmy Gonzales,  Dennis Quaid,  Anthony Gonza...
# 4  [Thanapob Leeratanakachorn,  Paris Intarakomal...
#
#                                  country date_added rating        genre  \
# 0                          United States 2021-09-25  PG-13  documentary
# 1  United States, United Kingdom, Canada 2021-09-01      R       action
# 2                            Desconocido 2021-06-30  TV-MA     thriller
# 3                          United States 2021-05-27  TV-PG        drama
# 4                               Thailand 2021-05-27  TV-MA       horror
#
#     premiere  imdb_score language  duration3
# 0 2020-10-02         7.5  English       90.0
# 1 2020-04-24         6.7  English       82.0
# 2 2021-04-14         5.7   Polish      101.0
# 3 2021-05-27         6.7  English      101.0
# 4 2021-05-26         5.2     Thai      118.0

# %%
df["genre"].value_counts()
# Out:
# documentary            132
# drama                   73
# comedy                  42
# romantic comedy         35
# thriller                33
#                       ...
# superhero/action         1
# dance comedy             1
# animation/superhero      1
# drama/horror             1
# mockumentary             1
# Name: genre, Length: 106, dtype: int64

# %%
cuenta_generos = Counter(elemento for generos in df["genre2"] for elemento in generos)
#cuenta_generos

# %%
diccionario_generos = dict(cuenta_generos.most_common(10))
diccionario_generos
# Out:
# {'documentary': 132,
#  'drama': 77,
#  'comedy': 50,
#  'thriller': 37,
#  'romantic comedy': 36,
#  'comedy-drama': 15,
#  'science fiction': 14,
#  'horror': 12,
#  'action': 11,
#  'crime drama': 11}

# %%
def sacar_parecido(col, diccionario):
    maximo = 0
    for key in diccionario:
        comparo = fuzz.ratio(key, col)

        if comparo > maximo:
            resultado = key
            maximo = comparo
            
            
    if maximo > 60:
        return resultado
    else:
        return "otro"

# %%
df["genre3"] = df.apply(lambda x: sacar_parecido(x["genre"],diccionario_generos ), axis = 1)

# %%
df.head()
# Out:
#                   title               director  \
# 0  Dick Johnson Is Dead      [Kirsten Johnson]
# 1            Extraction     [Steven C. Miller]
# 2            Prime Time         [Jakub Piątek]
# 3          Blue Miracle       [Julio Quintana]
# 4             Ghost Lab  [Paween Purijitpanya]
#
#                                                 cast  \
# 0                                      [Desconocido]
# 1  [Bruce Willis,  Kellan Lutz,  Gina Carano,  D....
# 2  [Bartosz Bielenia,  Magdalena Popławska,  Andr...
# 3  [Jimmy Gonzales,  Dennis Quaid,  Anthony Gonza...
# 4  [Thanapob Leeratanakachorn,  Paris Intarakomal...
#
#                                  country date_added rating        genre  \
# 0                          United States 2021-09-25  PG-13  documentary
# 1  United States, United Kingdom, Canada 2021-09-01      R       action
# 2                            Desconocido 2021-06-30  TV-MA     thriller
# 3                          United States 2021-05-27  TV-PG        drama
# 4                               Thailand 2021-05-27  TV-MA       horror
#
#     premiere  imdb_score language  duration3         genre2       genre3
# 0 2020-10-02         7.5  English       90.0  [documentary]  documentary
# 1 2020-04-24         6.7  English       82.0       [action]       action
# 2 2021-04-14         5.7   Polish      101.0     [thriller]     thriller
# 3 2021-05-27         6.7  English      101.0        [drama]        drama
# 4 2021-05-26         5.2     Thai      118.0       [horror]       horror

# %%
df["genre3"].value_counts()
# Out:
# documentary        133
# otro                83
# drama               75
# romantic comedy     57
# comedy              50
# thriller            47
# science fiction     17
# comedy-drama        17
# action              12
# crime drama         12
# horror              10
# Name: genre3, dtype: int64

# %%
fuzz.ratio("documetary", "patata")
# Out:
# 25

# %%
df.head()
# Out:
#                   title               director  \
# 0  Dick Johnson Is Dead      [Kirsten Johnson]
# 1            Extraction     [Steven C. Miller]
# 2            Prime Time         [Jakub Piątek]
# 3          Blue Miracle       [Julio Quintana]
# 4             Ghost Lab  [Paween Purijitpanya]
#
#                                                 cast  \
# 0                                      [Desconocido]
# 1  [Bruce Willis,  Kellan Lutz,  Gina Carano,  D....
# 2  [Bartosz Bielenia,  Magdalena Popławska,  Andr...
# 3  [Jimmy Gonzales,  Dennis Quaid,  Anthony Gonza...
# 4  [Thanapob Leeratanakachorn,  Paris Intarakomal...
#
#                                  country date_added rating        genre  \
# 0                          United States 2021-09-25  PG-13  documentary
# 1  United States, United Kingdom, Canada 2021-09-01      R       action
# 2                            Desconocido 2021-06-30  TV-MA     thriller
# 3                          United States 2021-05-27  TV-PG        drama
# 4                               Thailand 2021-05-27  TV-MA       horror
#
#     premiere  imdb_score language  duration3         genre2
# 0 2020-10-02         7.5  English       90.0  [documentary]
# 1 2020-04-24         6.7  English       82.0       [action]
# 2 2021-04-14         5.7   Polish      101.0     [thriller]
# 3 2021-05-27         6.7  English      101.0        [drama]
# 4 2021-05-26         5.2     Thai      118.0       [horror]

# %%
for generos in df["genre2"]:
    for elemento in generos:
        print(elemento)
# Out:
# documentary
# action
# thriller
# drama
# horror
# biopic
# documentary
# zombie
# heist
# comedy
# crime drama
# thriller
# psychological thriller
# science fiction thriller
# drama
# drama
# drama
# horror
# comedy
# drama
# animated musical comedy
# psychological thriller drama
# documentary
# drama
# superhero-comedy
# documentary
# drama
# romantic comedy
# drama
# drama
# christian musical
# hidden-camera prank comedy
# comedy-drama
# romantic teen drama
# documentary
# comedy
# drama
# action
# drama
# documentary
# romantic comedy
# thriller
# romantic drama
# romantic drama
# thriller
# romantic comedy
# comedy
# romantic drama
# science fiction
# documentary
# romantic drama
# drama
# drama
# drama
# drama
# comedy-drama
# action
# science fiction
# documentary
# comedy-drama
# documentary
# drama
# drama
# documentary
# documentary
# comedy
# animation
#  short
# comedy
# thriller
# superhero
# science fiction
# drama
# aftershow
#  interview
# romantic comedy
# animation
#  short
# documentary
# musical
# comedy
# thriller
# comedy
# comedy
# animation
# drama
# documentary
# drama
# drama
# concert film
# christmas comedy
# drama
# drama
# documentary
# stop motion
# animation
#  short
# romantic comedy
# family
# christmas musical
# drama
# anthology
# dark comedy
# drama
# drama
# romantic comedy
# thriller
# mystery
# crime drama
# drama
# romantic comedy
# holiday
# horror
# documentary
# documentary
# variety show
# animation
# musical
# adventure
# horror
# romantic thriller
# drama
# comedy
# fantasy
# family
# drama
# documentary
# documentary
# animation
# romantic comedy
# comedy
# documentary
# drama
# drama
# horror comedy
# romantic comedy
# action comedy
# documentary
# drama
# aftershow
#  interview
# documentary
# romantic comedy
# documentary
# thriller
# documentary
# family
# comedy
# horror
# drama
# horror
# documentary
# documentary
# psychological thriller
# romantic comedy
# romantic comedy
# drama
# thriller
# documentary
# drama
# thriller
# comedy
# documentary
# crime drama
# comedy-drama
# animation
# superhero
# animation
# superhero
# drama
# dance comedy
# documentary
# thriller
# comedy
# documentary
# thriller
# romantic comedy
# animation
# documentary
# thriller
# comedy
# documentary
# documentary
# superhero
# action
# documentary
# romantic comedy
# romantic teenage drama
# musical comedy
# documentary
# horror
# drama
# family
# comedy-drama
# thriller
# romance
# anime
# fantasy
# documentary
# war drama
# drama
# heist film
# thriller
# documentary
# thriller
# drama
# romantic comedy
# comedy
# documentary
# documentary
# drama
# thriller
# thriller
# romantic comedy
# documentary
# documentary
# thriller
# documentary
# animation
# comedy
# adventure
# action
# satire
# biopic
# documentary
# romantic comedy
# comedy
# drama
# action comedy
# anime
#  short
# romantic comedy
# thriller
# drama
# documentary
# thriller
# documentary
# sports film
# anime
# science fiction
# crime drama
# animation
#  short
# thriller
# action comedy
# political thriller
# drama
# romantic comedy
# romantic comedy
# drama
# documentary
# comedy
# thriller
# horror anthology
# science fiction
# drama
# drama
# documentary
# action
# drama
# romantic comedy
# aftershow
#  interview
# thriller
# family film
# crime drama
# romantic comedy
# documentary
# documentary
# mystery
# comedy
# animation
# christmas
# comedy
# adventure
# romantic comedy
# drama
# action
# documentary
# adventure-romance
# historical drama
# documentary
# documentary
# biopic
# documentary
# horror
# documentary
# horror
# coming-of-age comedy-drama
# documentary
# comedy-drama
# drama
# documentary
# drama
# crime drama
# thriller
# drama
# horror
# thriller
# documentary
# comedy
# documentary
# comedy-drama
# documentary
# aftershow
#  interview
# comedy
# romantic comedy
# documentary
# documentary
# animation
#  science fiction
# comedy
# animation
#  comedy
# documentary
# comedy
# spy thriller
# documentary
# thriller
# action
# drama
# documentary
# documentary
# comedy mystery
# romance
# documentary
# comedy
# documentary
# science fiction adventure
# horror-thriller
# comedy
#  musical
# documentary
# documentary
# science fiction
# drama
# comedy
# comedy
# documentary
# documentary
# drama
# romantic comedy
# drama
# romantic comedy
# comedy
# comedy-drama
# crime drama
# documentary
# documentary
# biopic
# documentary
# action-thriller
# drama
# drama
# comedy-drama
# drama
# drama-comedy
# romance drama
# documentary
# sports-drama
# variety show
# documentary
# thriller
# action
# science fiction
# drama
# crime drama
# documentary
# comedy-drama
# comedy
# psychological thriller
# one-man show
# documentary
# comedy
# adventure
# documentary
# documentary
# romantic comedy
# animation
# comedy-drama
# christmas
# fantasy
# adventure
# comedy
# psychological horror
# western
# romantic comedy
# one-man show
# historical-epic
# romantic comedy
# drama
# musical
# documentary
# mentalism special
# action-thriller
# horror-thriller
# documentary
# drama
# drama
# thriller
# documentary
# documentary
# spy thriller
# drama
# documentary
# crime drama
# documentary
# thriller
# comedy
# black comedy
# documentary
# comedy
# science fiction
# thriller
# documentary
# comedy
# action-thriller
# adventure
# comedy
# thriller
# documentary
# science fiction
# thriller
# romantic comedy
# drama
# romantic comedy
# romantic comedy
# comedy
# romantic comedy
# documentary
# drama
# drama
# comedy
# documentary
# comedy
# teen comedy-drama
# documentary
# biopic
# drama
# sports-drama
# documentary
# sports-drama
# romantic comedy
# action
# comedy
# musical
# western
# fantasy
# biopic
# family film
# documentary
# crime drama
# documentary
# science fiction
# mystery
# drama
# documentary
# romantic comedy
# science fiction
# biographical
# comedy
# comedy
# horror thriller
# comedy-drama
# urban fantasy
# romantic drama
# dark comedy
# documentary
# documentary
# romantic comedy
# western
# documentary
# horror
# crime drama
# documentary
# action thriller
# documentary
# teen comedy horror
# comedy-drama
# black comedy
# documentary
# horror thriller
# documentary
# romance
# documentary
# drama
# documentary
# documentary
# comedy horror
# documentary
# horror thriller
# comedy
# documentary
# comedy
# documentary
# drama
# action-adventure
# documentary
# crime thriller
# documentary
# war-comedy
# documentary
# documentary
# comedy
# documentary
# documentary
# one-man show
# dark comedy
# war
# romance
# comedy
# comedy
# science fiction
# drama
# biopic
# drama
# drama
# drama
# comedy
# drama
# comedy
# thriller
# heist
# biopic
# science fiction
# action
# thriller
# action comedy
# documentary
# horror
# documentary
# drama
# documentary
# mockumentary
# war
# documentary
# documentary
# science fiction
# thriller
# documentary
# documentary
# drama
# documentary
# comedy-drama
# thriller
# documentary
# comedy
# comedy-drama
# action comedy
# satire
# documentary
# documentary
# adventure
# western
# comedy
#  musical
# war drama
# documentary
# documentary
# documentary
# documentary
# documentary
# documentary
# documentary

# %%
df_director_top = df_director["director"].value_counts().reset_index().iloc[1:11, :]
df_director_top
# Out:
#                 index  director
# 1                 McG         3
# 2       Blair Simmons         2
# 3        John Schultz         2
# 4       Noah Baumbach         2
# 5         Karan Johar         2
# 6    Dibakar Banerjee         2
# 7     Julien Leclercq         2
# 8         Amy Poehler         2
# 9      Kyle Newacheck         2
# 10     Peter Sullivan         2

# %%
df_director_top = [dire.strip() for dire in df_director_top["index"].tolist()]
df_director_top
# Out:
# ['McG',
#  'Blair Simmons',
#  'John Schultz',
#  'Noah Baumbach',
#  'Karan Johar',
#  'Dibakar Banerjee',
#  'Julien Leclercq',
#  'Amy Poehler',
#  'Kyle Newacheck',
#  'Peter Sullivan']

# %%
with open("data/top_ten_director.pkl", "wb") as dire: 
    pickle.dump(df_director_top, dire)

# %% [markdown]
# Vemos que para la columna de `type` solo tenemos un tipo, ¿merece la pena entonces mantener esta columna? La verdad es que no, así que vamos a eliminarla

# %% [markdown]
# Dentro del análisis exploratorio es importante conocer todas las variables, con las categóricas es importante ver todas las categorías que tenemos para cada una de ellas y cuáles son sus frecuencias.

# %% [markdown]
# Si bien es cierto que hemos sacado todas la categóricas, ¿tiene sentido explorarlas todas? Podríamos pensar que variables como los títulos de cada peli no nos interesa, porque tienen demasiadas categorías. En este caso podremos eliminarlas de nuestro df_cat

# %% [markdown]
# Al ver todos los valores únicos podemos ver que las columnas de `lister_in` y `genre` nos dan la misma información, así que procedemos a eliminar una de ellas:

# %% [markdown]
# ## Limpieza `director`, `cast`, `country`
#
# Estas columnas eran las que tenían valores nulos

# %% [markdown]
# Imagineos que queremos cambiar el orden de las columnas, cambiemos el orden usando el método `reindex`.

# %% [markdown]
# # Limpiamos la columna de `duration`

# %% [markdown]
# # Limpiamos `date_added` y `premiere`

# %% [markdown]
# ## Clean `cast` y `director`

# %% [markdown]
# Aplicamos la misma lógica para la columna de directores

# %% [markdown]
# ## Limpiamos `genre`

# %% [markdown]
# # Top 10 directores y actores
